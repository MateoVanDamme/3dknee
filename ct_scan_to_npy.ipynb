# %% [markdown]
# # Reset variables and imports

# %%
# %reset -f
import pydicom

# %% [markdown]
# # Variables

# %%
datasets = {
    "preop": {
        "dicom_file": "./data/Gent_-_AZ_Jan-Palfijn_-_R240316084_01/DICOMDIR",
        "dicom_folder": "./data/Gent_-_AZ_Jan-Palfijn_-_R240316084_01/DICOM/",
        "good_slice_indices": (2, 1004),
        "output_folder": "data/ct_scan_knee_preop.npy"
    },
    "postop": {
        "dicom_file": "./data/Gent_-_AZ_Jan-Palfijn_-_R240503085_01/DICOMDIR",
        "dicom_folder": "./data/Gent_-_AZ_Jan-Palfijn_-_R240503085_01/DICOM/",
        "good_slice_indices": (3, 997),
        "output_folder": "data/ct_scan_knee_postop.npy"
    },
}

# Choose dataset
dataset_name = "preop"  # Change to "preop" to switch datasets

# Load selected dataset
dicom_file = datasets[dataset_name]["dicom_file"]
dicom_folder = datasets[dataset_name]["dicom_folder"]
good_slice_indices = datasets[dataset_name]["good_slice_indices"]
output_folder = datasets[dataset_name]["output_folder"]

print(f"Using {dataset_name} dataset: {dicom_folder}")
# Out:
# Using preop dataset: ./data/Gent_-_AZ_Jan-Palfijn_-_R240316084_01/DICOM/

# %% [markdown]
# # Overview of studies

# %%
# Load DICOMDIR file
dicomdir = pydicom.dcmread(dicom_file)

# Loop through the records
for record in dicomdir.DirectoryRecordSequence:
    if record.DirectoryRecordType == "PATIENT":
        print(f"Patient ID: {record.PatientID}")

    elif record.DirectoryRecordType == "STUDY":
        print(f"  Study: {record.StudyInstanceUID}")

    elif record.DirectoryRecordType == "SERIES":
        print(f"    Series: {record.SeriesInstanceUID}")

    elif record.DirectoryRecordType == "IMAGE":
        print(f"      Image File: {record.ReferencedFileID}")
# Out:
# Patient ID: 9903238260
#   Study: 1.2.840.113619.2.416.277363156194620470311478555430317444163
#     Series: 1.2.840.113619.2.416.154593166705332537822508406689549714628
#       Image File: ['DICOM', '000000']
#       Image File: ['DICOM', '000001']
#     Series: 1.2.840.113619.2.416.8736375049689656337108677189398888838
#       Image File: ['DICOM', '000002']
#       Image File: ['DICOM', '000003']
#       Image File: ['DICOM', '000004']
#       Image File: ['DICOM', '000005']
#       Image File: ['DICOM', '000006']
#       Image File: ['DICOM', '000007']
#       Image File: ['DICOM', '000008']
#       Image File: ['DICOM', '000009']
#       Image File: ['DICOM', '000010']
#       Image File: ['DICOM', '000011']
#       Image File: ['DICOM', '000012']
#       Image File: ['DICOM', '000013']
#       Image File: ['DICOM', '000014']
#       Image File: ['DICOM', '000015']
#       Image File: ['DICOM', '000016']
#       Image File: ['DICOM', '000017']
#       Image File: ['DICOM', '000018']
#       Image File: ['DICOM', '000019']
#       Image File: ['DICOM', '000020']
#       Image File: ['DICOM', '000021']
#       Image File: ['DICOM', '000022']
#       Image File: ['DICOM', '000023']
#       Image File: ['DICOM', '000024']
#       Image File: ['DICOM', '000025']
#       Image File: ['DICOM', '000026']
#       Image File: ['DICOM', '000027']
#       Image File: ['DICOM', '000028']
#       Image File: ['DICOM', '000029']
#       Image File: ['DICOM', '000030']
#       Image File: ['DICOM', '000031']
#       Image File: ['DICOM', '000032']
#       Image File: ['DICOM', '000033']
#       Image File: ['DICOM', '000034']
#       Image File: ['DICOM', '000035']
#       Image File: ['DICOM', '000036']
#       Image File: ['DICOM', '000037']
#       Image File: ['DICOM', '000038']
#       Image File: ['DICOM', '000039']
#       Image File: ['DICOM', '000040']
#       Image File: ['DICOM', '000041']
#       Image File: ['DICOM', '000042']
#       Image File: ['DICOM', '000043']
#       Image File: ['DICOM', '000044']
#       Image File: ['DICOM', '000045']
#       Image File: ['DICOM', '000046']
#       Image File: ['DICOM', '000047']
#       Image File: ['DICOM', '000048']
#       Image File: ['DICOM', '000049']
#       Image File: ['DICOM', '000050']
#       Image File: ['DICOM', '000051']
#       Image File: ['DICOM', '000052']
#       Image File: ['DICOM', '000053']
#       Image File: ['DICOM', '000054']
#       Image File: ['DICOM', '000055']
#       Image File: ['DICOM', '000056']
#       Image File: ['DICOM', '000057']
#       Image File: ['DICOM', '000058']
#       Image File: ['DICOM', '000059']
#       Image File: ['DICOM', '000060']
#       Image File: ['DICOM', '000061']
#       Image File: ['DICOM', '000062']
#       Image File: ['DICOM', '000063']
#       Image File: ['DICOM', '000064']
#       Image File: ['DICOM', '000065']
#       Image File: ['DICOM', '000066']
#       Image File: ['DICOM', '000067']
#       Image File: ['DICOM', '000068']
#       Image File: ['DICOM', '000069']
#       Image File: ['DICOM', '000070']
#       Image File: ['DICOM', '000071']
#       Image File: ['DICOM', '000072']
#       Image File: ['DICOM', '000073']
#       Image File: ['DICOM', '000074']
#       Image File: ['DICOM', '000075']
#       Image File: ['DICOM', '000076']
#       Image File: ['DICOM', '000077']
#       Image File: ['DICOM', '000078']
#       Image File: ['DICOM', '000079']
#       Image File: ['DICOM', '000080']
#       Image File: ['DICOM', '000081']
#       Image File: ['DICOM', '000082']
#       Image File: ['DICOM', '000083']
#       Image File: ['DICOM', '000084']
#       Image File: ['DICOM', '000085']
#       Image File: ['DICOM', '000086']
#       Image File: ['DICOM', '000087']
#       Image File: ['DICOM', '000088']
#       Image File: ['DICOM', '000089']
#       Image File: ['DICOM', '000090']
#       Image File: ['DICOM', '000091']
#       Image File: ['DICOM', '000092']
#       Image File: ['DICOM', '000093']
#       Image File: ['DICOM', '000094']
#       Image File: ['DICOM', '000095']
#       Image File: ['DICOM', '000096']
#       Image File: ['DICOM', '000097']
#       Image File: ['DICOM', '000098']
#       Image File: ['DICOM', '000099']
#       Image File: ['DICOM', '000100']
#       Image File: ['DICOM', '000101']
#       Image File: ['DICOM', '000102']
#       Image File: ['DICOM', '000103']
#       Image File: ['DICOM', '000104']
#       Image File: ['DICOM', '000105']
#       Image File: ['DICOM', '000106']
#       Image File: ['DICOM', '000107']
#       Image File: ['DICOM', '000108']
#       Image File: ['DICOM', '000109']
#       Image File: ['DICOM', '000110']
#       Image File: ['DICOM', '000111']
#       Image File: ['DICOM', '000112']
#       Image File: ['DICOM', '000113']
#       Image File: ['DICOM', '000114']
#       Image File: ['DICOM', '000115']
#       Image File: ['DICOM', '000116']
#       Image File: ['DICOM', '000117']
#       Image File: ['DICOM', '000118']
#       Image File: ['DICOM', '000119']
#       Image File: ['DICOM', '000120']
#       Image File: ['DICOM', '000121']
#       Image File: ['DICOM', '000122']
#       Image File: ['DICOM', '000123']
#       Image File: ['DICOM', '000124']
#       Image File: ['DICOM', '000125']
#       Image File: ['DICOM', '000126']
#       Image File: ['DICOM', '000127']
#       Image File: ['DICOM', '000128']
#       Image File: ['DICOM', '000129']
#       Image File: ['DICOM', '000130']
#       Image File: ['DICOM', '000131']
#       Image File: ['DICOM', '000132']
#       Image File: ['DICOM', '000133']
#       Image File: ['DICOM', '000134']
#       Image File: ['DICOM', '000135']
#       Image File: ['DICOM', '000136']
#       Image File: ['DICOM', '000137']
#       Image File: ['DICOM', '000138']
#       Image File: ['DICOM', '000139']
#       Image File: ['DICOM', '000140']
#       Image File: ['DICOM', '000141']
#       Image File: ['DICOM', '000142']
#       Image File: ['DICOM', '000143']
#       Image File: ['DICOM', '000144']
#       Image File: ['DICOM', '000145']
#       Image File: ['DICOM', '000146']
#       Image File: ['DICOM', '000147']
#       Image File: ['DICOM', '000148']
#       Image File: ['DICOM', '000149']
#       Image File: ['DICOM', '000150']
#       Image File: ['DICOM', '000151']
#       Image File: ['DICOM', '000152']
#       Image File: ['DICOM', '000153']
#       Image File: ['DICOM', '000154']
#       Image File: ['DICOM', '000155']
#       Image File: ['DICOM', '000156']
#       Image File: ['DICOM', '000157']
#       Image File: ['DICOM', '000158']
#       Image File: ['DICOM', '000159']
#       Image File: ['DICOM', '000160']
#       Image File: ['DICOM', '000161']
#       Image File: ['DICOM', '000162']
#       Image File: ['DICOM', '000163']
#       Image File: ['DICOM', '000164']
#       Image File: ['DICOM', '000165']
#       Image File: ['DICOM', '000166']
#       Image File: ['DICOM', '000167']
#       Image File: ['DICOM', '000168']
#       Image File: ['DICOM', '000169']
#       Image File: ['DICOM', '000170']
#       Image File: ['DICOM', '000171']
#       Image File: ['DICOM', '000172']
#       Image File: ['DICOM', '000173']
#       Image File: ['DICOM', '000174']
#       Image File: ['DICOM', '000175']
#       Image File: ['DICOM', '000176']
#       Image File: ['DICOM', '000177']
#       Image File: ['DICOM', '000178']
#       Image File: ['DICOM', '000179']
#       Image File: ['DICOM', '000180']
#       Image File: ['DICOM', '000181']
#       Image File: ['DICOM', '000182']
#       Image File: ['DICOM', '000183']
#       Image File: ['DICOM', '000184']
#       Image File: ['DICOM', '000185']
#       Image File: ['DICOM', '000186']
#       Image File: ['DICOM', '000187']
#       Image File: ['DICOM', '000188']
#       Image File: ['DICOM', '000189']
#       Image File: ['DICOM', '000190']
#       Image File: ['DICOM', '000191']
#       Image File: ['DICOM', '000192']
#       Image File: ['DICOM', '000193']
#       Image File: ['DICOM', '000194']
#       Image File: ['DICOM', '000195']
#       Image File: ['DICOM', '000196']
#       Image File: ['DICOM', '000197']
#       Image File: ['DICOM', '000198']
#       Image File: ['DICOM', '000199']
#       Image File: ['DICOM', '000200']
#       Image File: ['DICOM', '000201']
#       Image File: ['DICOM', '000202']
#       Image File: ['DICOM', '000203']
#       Image File: ['DICOM', '000204']
#       Image File: ['DICOM', '000205']
#       Image File: ['DICOM', '000206']
#       Image File: ['DICOM', '000207']
#       Image File: ['DICOM', '000208']
#       Image File: ['DICOM', '000209']
#       Image File: ['DICOM', '000210']
#       Image File: ['DICOM', '000211']
#       Image File: ['DICOM', '000212']
#       Image File: ['DICOM', '000213']
#       Image File: ['DICOM', '000214']
#       Image File: ['DICOM', '000215']
#       Image File: ['DICOM', '000216']
#       Image File: ['DICOM', '000217']
#       Image File: ['DICOM', '000218']
#       Image File: ['DICOM', '000219']
#       Image File: ['DICOM', '000220']
#       Image File: ['DICOM', '000221']
#       Image File: ['DICOM', '000222']
#       Image File: ['DICOM', '000223']
#       Image File: ['DICOM', '000224']
#       Image File: ['DICOM', '000225']
#       Image File: ['DICOM', '000226']
#       Image File: ['DICOM', '000227']
#       Image File: ['DICOM', '000228']
#       Image File: ['DICOM', '000229']
#       Image File: ['DICOM', '000230']
#       Image File: ['DICOM', '000231']
#       Image File: ['DICOM', '000232']
#       Image File: ['DICOM', '000233']
#       Image File: ['DICOM', '000234']
#       Image File: ['DICOM', '000235']
#       Image File: ['DICOM', '000236']
#       Image File: ['DICOM', '000237']
#       Image File: ['DICOM', '000238']
#       Image File: ['DICOM', '000239']
#       Image File: ['DICOM', '000240']
#       Image File: ['DICOM', '000241']
#       Image File: ['DICOM', '000242']
#       Image File: ['DICOM', '000243']
#       Image File: ['DICOM', '000244']
#       Image File: ['DICOM', '000245']
#       Image File: ['DICOM', '000246']
#       Image File: ['DICOM', '000247']
#       Image File: ['DICOM', '000248']
#       Image File: ['DICOM', '000249']
#       Image File: ['DICOM', '000250']
#       Image File: ['DICOM', '000251']
#       Image File: ['DICOM', '000252']
#       Image File: ['DICOM', '000253']
#       Image File: ['DICOM', '000254']
#       Image File: ['DICOM', '000255']
#       Image File: ['DICOM', '000256']
#       Image File: ['DICOM', '000257']
#       Image File: ['DICOM', '000258']
#       Image File: ['DICOM', '000259']
#       Image File: ['DICOM', '000260']
#       Image File: ['DICOM', '000261']
#       Image File: ['DICOM', '000262']
#       Image File: ['DICOM', '000263']
#       Image File: ['DICOM', '000264']
#       Image File: ['DICOM', '000265']
#       Image File: ['DICOM', '000266']
#       Image File: ['DICOM', '000267']
#       Image File: ['DICOM', '000268']
#       Image File: ['DICOM', '000269']
#       Image File: ['DICOM', '000270']
#       Image File: ['DICOM', '000271']
#       Image File: ['DICOM', '000272']
#       Image File: ['DICOM', '000273']
#       Image File: ['DICOM', '000274']
#       Image File: ['DICOM', '000275']
#       Image File: ['DICOM', '000276']
#       Image File: ['DICOM', '000277']
#       Image File: ['DICOM', '000278']
#       Image File: ['DICOM', '000279']
#       Image File: ['DICOM', '000280']
#       Image File: ['DICOM', '000281']
#       Image File: ['DICOM', '000282']
#       Image File: ['DICOM', '000283']
#       Image File: ['DICOM', '000284']
#       Image File: ['DICOM', '000285']
#       Image File: ['DICOM', '000286']
#       Image File: ['DICOM', '000287']
#       Image File: ['DICOM', '000288']
#       Image File: ['DICOM', '000289']
#       Image File: ['DICOM', '000290']
#       Image File: ['DICOM', '000291']
#       Image File: ['DICOM', '000292']
#       Image File: ['DICOM', '000293']
#       Image File: ['DICOM', '000294']
#       Image File: ['DICOM', '000295']
#       Image File: ['DICOM', '000296']
#       Image File: ['DICOM', '000297']
#       Image File: ['DICOM', '000298']
#       Image File: ['DICOM', '000299']
#       Image File: ['DICOM', '000300']
#       Image File: ['DICOM', '000301']
#       Image File: ['DICOM', '000302']
#       Image File: ['DICOM', '000303']
#       Image File: ['DICOM', '000304']
#       Image File: ['DICOM', '000305']
#       Image File: ['DICOM', '000306']
#       Image File: ['DICOM', '000307']
#       Image File: ['DICOM', '000308']
#       Image File: ['DICOM', '000309']
#       Image File: ['DICOM', '000310']
#       Image File: ['DICOM', '000311']
#       Image File: ['DICOM', '000312']
#       Image File: ['DICOM', '000313']
#       Image File: ['DICOM', '000314']
#       Image File: ['DICOM', '000315']
#       Image File: ['DICOM', '000316']
#       Image File: ['DICOM', '000317']
#       Image File: ['DICOM', '000318']
#       Image File: ['DICOM', '000319']
#       Image File: ['DICOM', '000320']
#       Image File: ['DICOM', '000321']
#       Image File: ['DICOM', '000322']
#       Image File: ['DICOM', '000323']
#       Image File: ['DICOM', '000324']
#       Image File: ['DICOM', '000325']
#       Image File: ['DICOM', '000326']
#       Image File: ['DICOM', '000327']
#       Image File: ['DICOM', '000328']
#       Image File: ['DICOM', '000329']
#       Image File: ['DICOM', '000330']
#       Image File: ['DICOM', '000331']
#       Image File: ['DICOM', '000332']
#       Image File: ['DICOM', '000333']
#       Image File: ['DICOM', '000334']
#       Image File: ['DICOM', '000335']
#       Image File: ['DICOM', '000336']
#       Image File: ['DICOM', '000337']
#       Image File: ['DICOM', '000338']
#       Image File: ['DICOM', '000339']
#       Image File: ['DICOM', '000340']
#       Image File: ['DICOM', '000341']
#       Image File: ['DICOM', '000342']
#       Image File: ['DICOM', '000343']
#       Image File: ['DICOM', '000344']
#       Image File: ['DICOM', '000345']
#       Image File: ['DICOM', '000346']
#       Image File: ['DICOM', '000347']
#       Image File: ['DICOM', '000348']
#       Image File: ['DICOM', '000349']
#       Image File: ['DICOM', '000350']
#       Image File: ['DICOM', '000351']
#       Image File: ['DICOM', '000352']
#       Image File: ['DICOM', '000353']
#       Image File: ['DICOM', '000354']
#       Image File: ['DICOM', '000355']
#       Image File: ['DICOM', '000356']
#       Image File: ['DICOM', '000357']
#       Image File: ['DICOM', '000358']
#       Image File: ['DICOM', '000359']
#       Image File: ['DICOM', '000360']
#       Image File: ['DICOM', '000361']
#       Image File: ['DICOM', '000362']
#       Image File: ['DICOM', '000363']
#       Image File: ['DICOM', '000364']
#       Image File: ['DICOM', '000365']
#       Image File: ['DICOM', '000366']
#       Image File: ['DICOM', '000367']
#       Image File: ['DICOM', '000368']
#       Image File: ['DICOM', '000369']
#       Image File: ['DICOM', '000370']
#       Image File: ['DICOM', '000371']
#       Image File: ['DICOM', '000372']
#       Image File: ['DICOM', '000373']
#       Image File: ['DICOM', '000374']
#       Image File: ['DICOM', '000375']
#       Image File: ['DICOM', '000376']
#       Image File: ['DICOM', '000377']
#       Image File: ['DICOM', '000378']
#       Image File: ['DICOM', '000379']
#       Image File: ['DICOM', '000380']
#       Image File: ['DICOM', '000381']
#       Image File: ['DICOM', '000382']
#       Image File: ['DICOM', '000383']
#       Image File: ['DICOM', '000384']
#       Image File: ['DICOM', '000385']
#       Image File: ['DICOM', '000386']
#       Image File: ['DICOM', '000387']
#       Image File: ['DICOM', '000388']
#       Image File: ['DICOM', '000389']
#       Image File: ['DICOM', '000390']
#       Image File: ['DICOM', '000391']
#       Image File: ['DICOM', '000392']
#       Image File: ['DICOM', '000393']
#       Image File: ['DICOM', '000394']
#       Image File: ['DICOM', '000395']
#       Image File: ['DICOM', '000396']
#       Image File: ['DICOM', '000397']
#       Image File: ['DICOM', '000398']
#       Image File: ['DICOM', '000399']
#       Image File: ['DICOM', '000400']
#       Image File: ['DICOM', '000401']
#       Image File: ['DICOM', '000402']
#       Image File: ['DICOM', '000403']
#       Image File: ['DICOM', '000404']
#       Image File: ['DICOM', '000405']
#       Image File: ['DICOM', '000406']
#       Image File: ['DICOM', '000407']
#       Image File: ['DICOM', '000408']
#       Image File: ['DICOM', '000409']
#       Image File: ['DICOM', '000410']
#       Image File: ['DICOM', '000411']
#       Image File: ['DICOM', '000412']
#       Image File: ['DICOM', '000413']
#       Image File: ['DICOM', '000414']
#       Image File: ['DICOM', '000415']
#       Image File: ['DICOM', '000416']
#       Image File: ['DICOM', '000417']
#       Image File: ['DICOM', '000418']
#       Image File: ['DICOM', '000419']
#       Image File: ['DICOM', '000420']
#       Image File: ['DICOM', '000421']
#       Image File: ['DICOM', '000422']
#       Image File: ['DICOM', '000423']
#       Image File: ['DICOM', '000424']
#       Image File: ['DICOM', '000425']
#       Image File: ['DICOM', '000426']
#       Image File: ['DICOM', '000427']
#       Image File: ['DICOM', '000428']
#       Image File: ['DICOM', '000429']
#       Image File: ['DICOM', '000430']
#       Image File: ['DICOM', '000431']
#       Image File: ['DICOM', '000432']
#       Image File: ['DICOM', '000433']
#       Image File: ['DICOM', '000434']
#       Image File: ['DICOM', '000435']
#       Image File: ['DICOM', '000436']
#       Image File: ['DICOM', '000437']
#       Image File: ['DICOM', '000438']
#       Image File: ['DICOM', '000439']
#       Image File: ['DICOM', '000440']
#       Image File: ['DICOM', '000441']
#       Image File: ['DICOM', '000442']
#       Image File: ['DICOM', '000443']
#       Image File: ['DICOM', '000444']
#       Image File: ['DICOM', '000445']
#       Image File: ['DICOM', '000446']
#       Image File: ['DICOM', '000447']
#       Image File: ['DICOM', '000448']
#       Image File: ['DICOM', '000449']
#       Image File: ['DICOM', '000450']
#       Image File: ['DICOM', '000451']
#       Image File: ['DICOM', '000452']
#       Image File: ['DICOM', '000453']
#       Image File: ['DICOM', '000454']
#       Image File: ['DICOM', '000455']
#       Image File: ['DICOM', '000456']
#       Image File: ['DICOM', '000457']
#       Image File: ['DICOM', '000458']
#       Image File: ['DICOM', '000459']
#       Image File: ['DICOM', '000460']
#       Image File: ['DICOM', '000461']
#       Image File: ['DICOM', '000462']
#       Image File: ['DICOM', '000463']
#       Image File: ['DICOM', '000464']
#       Image File: ['DICOM', '000465']
#       Image File: ['DICOM', '000466']
#       Image File: ['DICOM', '000467']
#       Image File: ['DICOM', '000468']
#       Image File: ['DICOM', '000469']
#       Image File: ['DICOM', '000470']
#       Image File: ['DICOM', '000471']
#       Image File: ['DICOM', '000472']
#       Image File: ['DICOM', '000473']
#       Image File: ['DICOM', '000474']
#       Image File: ['DICOM', '000475']
#       Image File: ['DICOM', '000476']
#       Image File: ['DICOM', '000477']
#       Image File: ['DICOM', '000478']
#       Image File: ['DICOM', '000479']
#       Image File: ['DICOM', '000480']
#       Image File: ['DICOM', '000481']
#       Image File: ['DICOM', '000482']
#       Image File: ['DICOM', '000483']
#       Image File: ['DICOM', '000484']
#       Image File: ['DICOM', '000485']
#       Image File: ['DICOM', '000486']
#       Image File: ['DICOM', '000487']
#       Image File: ['DICOM', '000488']
#       Image File: ['DICOM', '000489']
#       Image File: ['DICOM', '000490']
#       Image File: ['DICOM', '000491']
#       Image File: ['DICOM', '000492']
#       Image File: ['DICOM', '000493']
#       Image File: ['DICOM', '000494']
#       Image File: ['DICOM', '000495']
#       Image File: ['DICOM', '000496']
#       Image File: ['DICOM', '000497']
#       Image File: ['DICOM', '000498']
#       Image File: ['DICOM', '000499']
#       Image File: ['DICOM', '000500']
#       Image File: ['DICOM', '000501']
#       Image File: ['DICOM', '000502']
#       Image File: ['DICOM', '000503']
#       Image File: ['DICOM', '000504']
#       Image File: ['DICOM', '000505']
#       Image File: ['DICOM', '000506']
#       Image File: ['DICOM', '000507']
#       Image File: ['DICOM', '000508']
#       Image File: ['DICOM', '000509']
#       Image File: ['DICOM', '000510']
#       Image File: ['DICOM', '000511']
#       Image File: ['DICOM', '000512']
#       Image File: ['DICOM', '000513']
#       Image File: ['DICOM', '000514']
#       Image File: ['DICOM', '000515']
#       Image File: ['DICOM', '000516']
#       Image File: ['DICOM', '000517']
#       Image File: ['DICOM', '000518']
#       Image File: ['DICOM', '000519']
#       Image File: ['DICOM', '000520']
#       Image File: ['DICOM', '000521']
#       Image File: ['DICOM', '000522']
#       Image File: ['DICOM', '000523']
#       Image File: ['DICOM', '000524']
#       Image File: ['DICOM', '000525']
#       Image File: ['DICOM', '000526']
#       Image File: ['DICOM', '000527']
#       Image File: ['DICOM', '000528']
#       Image File: ['DICOM', '000529']
#       Image File: ['DICOM', '000530']
#       Image File: ['DICOM', '000531']
#       Image File: ['DICOM', '000532']
#       Image File: ['DICOM', '000533']
#       Image File: ['DICOM', '000534']
#       Image File: ['DICOM', '000535']
#       Image File: ['DICOM', '000536']
#       Image File: ['DICOM', '000537']
#       Image File: ['DICOM', '000538']
#       Image File: ['DICOM', '000539']
#       Image File: ['DICOM', '000540']
#       Image File: ['DICOM', '000541']
#       Image File: ['DICOM', '000542']
#       Image File: ['DICOM', '000543']
#       Image File: ['DICOM', '000544']
#       Image File: ['DICOM', '000545']
#       Image File: ['DICOM', '000546']
#       Image File: ['DICOM', '000547']
#       Image File: ['DICOM', '000548']
#       Image File: ['DICOM', '000549']
#       Image File: ['DICOM', '000550']
#       Image File: ['DICOM', '000551']
#       Image File: ['DICOM', '000552']
#       Image File: ['DICOM', '000553']
#       Image File: ['DICOM', '000554']
#       Image File: ['DICOM', '000555']
#       Image File: ['DICOM', '000556']
#       Image File: ['DICOM', '000557']
#       Image File: ['DICOM', '000558']
#       Image File: ['DICOM', '000559']
#       Image File: ['DICOM', '000560']
#       Image File: ['DICOM', '000561']
#       Image File: ['DICOM', '000562']
#       Image File: ['DICOM', '000563']
#       Image File: ['DICOM', '000564']
#       Image File: ['DICOM', '000565']
#       Image File: ['DICOM', '000566']
#       Image File: ['DICOM', '000567']
#       Image File: ['DICOM', '000568']
#       Image File: ['DICOM', '000569']
#       Image File: ['DICOM', '000570']
#       Image File: ['DICOM', '000571']
#       Image File: ['DICOM', '000572']
#       Image File: ['DICOM', '000573']
#       Image File: ['DICOM', '000574']
#       Image File: ['DICOM', '000575']
#       Image File: ['DICOM', '000576']
#       Image File: ['DICOM', '000577']
#       Image File: ['DICOM', '000578']
#       Image File: ['DICOM', '000579']
#       Image File: ['DICOM', '000580']
#       Image File: ['DICOM', '000581']
#       Image File: ['DICOM', '000582']
#       Image File: ['DICOM', '000583']
#       Image File: ['DICOM', '000584']
#       Image File: ['DICOM', '000585']
#       Image File: ['DICOM', '000586']
#       Image File: ['DICOM', '000587']
#       Image File: ['DICOM', '000588']
#       Image File: ['DICOM', '000589']
#       Image File: ['DICOM', '000590']
#       Image File: ['DICOM', '000591']
#       Image File: ['DICOM', '000592']
#       Image File: ['DICOM', '000593']
#       Image File: ['DICOM', '000594']
#       Image File: ['DICOM', '000595']
#       Image File: ['DICOM', '000596']
#       Image File: ['DICOM', '000597']
#       Image File: ['DICOM', '000598']
#       Image File: ['DICOM', '000599']
#       Image File: ['DICOM', '000600']
#       Image File: ['DICOM', '000601']
#       Image File: ['DICOM', '000602']
#       Image File: ['DICOM', '000603']
#       Image File: ['DICOM', '000604']
#       Image File: ['DICOM', '000605']
#       Image File: ['DICOM', '000606']
#       Image File: ['DICOM', '000607']
#       Image File: ['DICOM', '000608']
#       Image File: ['DICOM', '000609']
#       Image File: ['DICOM', '000610']
#       Image File: ['DICOM', '000611']
#       Image File: ['DICOM', '000612']
#       Image File: ['DICOM', '000613']
#       Image File: ['DICOM', '000614']
#       Image File: ['DICOM', '000615']
#       Image File: ['DICOM', '000616']
#       Image File: ['DICOM', '000617']
#       Image File: ['DICOM', '000618']
#       Image File: ['DICOM', '000619']
#       Image File: ['DICOM', '000620']
#       Image File: ['DICOM', '000621']
#       Image File: ['DICOM', '000622']
#       Image File: ['DICOM', '000623']
#       Image File: ['DICOM', '000624']
#       Image File: ['DICOM', '000625']
#       Image File: ['DICOM', '000626']
#       Image File: ['DICOM', '000627']
#       Image File: ['DICOM', '000628']
#       Image File: ['DICOM', '000629']
#       Image File: ['DICOM', '000630']
#       Image File: ['DICOM', '000631']
#       Image File: ['DICOM', '000632']
#       Image File: ['DICOM', '000633']
#       Image File: ['DICOM', '000634']
#       Image File: ['DICOM', '000635']
#       Image File: ['DICOM', '000636']
#       Image File: ['DICOM', '000637']
#       Image File: ['DICOM', '000638']
#       Image File: ['DICOM', '000639']
#       Image File: ['DICOM', '000640']
#       Image File: ['DICOM', '000641']
#       Image File: ['DICOM', '000642']
#       Image File: ['DICOM', '000643']
#       Image File: ['DICOM', '000644']
#       Image File: ['DICOM', '000645']
#       Image File: ['DICOM', '000646']
#       Image File: ['DICOM', '000647']
#       Image File: ['DICOM', '000648']
#       Image File: ['DICOM', '000649']
#       Image File: ['DICOM', '000650']
#       Image File: ['DICOM', '000651']
#       Image File: ['DICOM', '000652']
#       Image File: ['DICOM', '000653']
#       Image File: ['DICOM', '000654']
#       Image File: ['DICOM', '000655']
#       Image File: ['DICOM', '000656']
#       Image File: ['DICOM', '000657']
#       Image File: ['DICOM', '000658']
#       Image File: ['DICOM', '000659']
#       Image File: ['DICOM', '000660']
#       Image File: ['DICOM', '000661']
#       Image File: ['DICOM', '000662']
#       Image File: ['DICOM', '000663']
#       Image File: ['DICOM', '000664']
#       Image File: ['DICOM', '000665']
#       Image File: ['DICOM', '000666']
#       Image File: ['DICOM', '000667']
#       Image File: ['DICOM', '000668']
#       Image File: ['DICOM', '000669']
#       Image File: ['DICOM', '000670']
#       Image File: ['DICOM', '000671']
#       Image File: ['DICOM', '000672']
#       Image File: ['DICOM', '000673']
#       Image File: ['DICOM', '000674']
#       Image File: ['DICOM', '000675']
#       Image File: ['DICOM', '000676']
#       Image File: ['DICOM', '000677']
#       Image File: ['DICOM', '000678']
#       Image File: ['DICOM', '000679']
#       Image File: ['DICOM', '000680']
#       Image File: ['DICOM', '000681']
#       Image File: ['DICOM', '000682']
#       Image File: ['DICOM', '000683']
#       Image File: ['DICOM', '000684']
#       Image File: ['DICOM', '000685']
#       Image File: ['DICOM', '000686']
#       Image File: ['DICOM', '000687']
#       Image File: ['DICOM', '000688']
#       Image File: ['DICOM', '000689']
#       Image File: ['DICOM', '000690']
#       Image File: ['DICOM', '000691']
#       Image File: ['DICOM', '000692']
#       Image File: ['DICOM', '000693']
#       Image File: ['DICOM', '000694']
#       Image File: ['DICOM', '000695']
#       Image File: ['DICOM', '000696']
#       Image File: ['DICOM', '000697']
#       Image File: ['DICOM', '000698']
#       Image File: ['DICOM', '000699']
#       Image File: ['DICOM', '000700']
#       Image File: ['DICOM', '000701']
#       Image File: ['DICOM', '000702']
#       Image File: ['DICOM', '000703']
#       Image File: ['DICOM', '000704']
#       Image File: ['DICOM', '000705']
#       Image File: ['DICOM', '000706']
#       Image File: ['DICOM', '000707']
#       Image File: ['DICOM', '000708']
#       Image File: ['DICOM', '000709']
#       Image File: ['DICOM', '000710']
#       Image File: ['DICOM', '000711']
#       Image File: ['DICOM', '000712']
#       Image File: ['DICOM', '000713']
#       Image File: ['DICOM', '000714']
#       Image File: ['DICOM', '000715']
#       Image File: ['DICOM', '000716']
#       Image File: ['DICOM', '000717']
#       Image File: ['DICOM', '000718']
#       Image File: ['DICOM', '000719']
#       Image File: ['DICOM', '000720']
#       Image File: ['DICOM', '000721']
#       Image File: ['DICOM', '000722']
#       Image File: ['DICOM', '000723']
#       Image File: ['DICOM', '000724']
#       Image File: ['DICOM', '000725']
#       Image File: ['DICOM', '000726']
#       Image File: ['DICOM', '000727']
#       Image File: ['DICOM', '000728']
#       Image File: ['DICOM', '000729']
#       Image File: ['DICOM', '000730']
#       Image File: ['DICOM', '000731']
#       Image File: ['DICOM', '000732']
#       Image File: ['DICOM', '000733']
#       Image File: ['DICOM', '000734']
#       Image File: ['DICOM', '000735']
#       Image File: ['DICOM', '000736']
#       Image File: ['DICOM', '000737']
#       Image File: ['DICOM', '000738']
#       Image File: ['DICOM', '000739']
#       Image File: ['DICOM', '000740']
#       Image File: ['DICOM', '000741']
#       Image File: ['DICOM', '000742']
#       Image File: ['DICOM', '000743']
#       Image File: ['DICOM', '000744']
#       Image File: ['DICOM', '000745']
#       Image File: ['DICOM', '000746']
#       Image File: ['DICOM', '000747']
#       Image File: ['DICOM', '000748']
#       Image File: ['DICOM', '000749']
#       Image File: ['DICOM', '000750']
#       Image File: ['DICOM', '000751']
#       Image File: ['DICOM', '000752']
#       Image File: ['DICOM', '000753']
#       Image File: ['DICOM', '000754']
#       Image File: ['DICOM', '000755']
#       Image File: ['DICOM', '000756']
#       Image File: ['DICOM', '000757']
#       Image File: ['DICOM', '000758']
#       Image File: ['DICOM', '000759']
#       Image File: ['DICOM', '000760']
#       Image File: ['DICOM', '000761']
#       Image File: ['DICOM', '000762']
#       Image File: ['DICOM', '000763']
#       Image File: ['DICOM', '000764']
#       Image File: ['DICOM', '000765']
#       Image File: ['DICOM', '000766']
#       Image File: ['DICOM', '000767']
#       Image File: ['DICOM', '000768']
#       Image File: ['DICOM', '000769']
#       Image File: ['DICOM', '000770']
#       Image File: ['DICOM', '000771']
#       Image File: ['DICOM', '000772']
#       Image File: ['DICOM', '000773']
#       Image File: ['DICOM', '000774']
#       Image File: ['DICOM', '000775']
#       Image File: ['DICOM', '000776']
#       Image File: ['DICOM', '000777']
#       Image File: ['DICOM', '000778']
#       Image File: ['DICOM', '000779']
#       Image File: ['DICOM', '000780']
#       Image File: ['DICOM', '000781']
#       Image File: ['DICOM', '000782']
#       Image File: ['DICOM', '000783']
#       Image File: ['DICOM', '000784']
#       Image File: ['DICOM', '000785']
#       Image File: ['DICOM', '000786']
#       Image File: ['DICOM', '000787']
#       Image File: ['DICOM', '000788']
#       Image File: ['DICOM', '000789']
#       Image File: ['DICOM', '000790']
#       Image File: ['DICOM', '000791']
#       Image File: ['DICOM', '000792']
#       Image File: ['DICOM', '000793']
#       Image File: ['DICOM', '000794']
#       Image File: ['DICOM', '000795']
#       Image File: ['DICOM', '000796']
#       Image File: ['DICOM', '000797']
#       Image File: ['DICOM', '000798']
#       Image File: ['DICOM', '000799']
#       Image File: ['DICOM', '000800']
#       Image File: ['DICOM', '000801']
#       Image File: ['DICOM', '000802']
#       Image File: ['DICOM', '000803']
#       Image File: ['DICOM', '000804']
#       Image File: ['DICOM', '000805']
#       Image File: ['DICOM', '000806']
#       Image File: ['DICOM', '000807']
#       Image File: ['DICOM', '000808']
#       Image File: ['DICOM', '000809']
#       Image File: ['DICOM', '000810']
#       Image File: ['DICOM', '000811']
#       Image File: ['DICOM', '000812']
#       Image File: ['DICOM', '000813']
#       Image File: ['DICOM', '000814']
#       Image File: ['DICOM', '000815']
#       Image File: ['DICOM', '000816']
#       Image File: ['DICOM', '000817']
#       Image File: ['DICOM', '000818']
#       Image File: ['DICOM', '000819']
#       Image File: ['DICOM', '000820']
#       Image File: ['DICOM', '000821']
#       Image File: ['DICOM', '000822']
#       Image File: ['DICOM', '000823']
#       Image File: ['DICOM', '000824']
#       Image File: ['DICOM', '000825']
#       Image File: ['DICOM', '000826']
#       Image File: ['DICOM', '000827']
#       Image File: ['DICOM', '000828']
#       Image File: ['DICOM', '000829']
#       Image File: ['DICOM', '000830']
#       Image File: ['DICOM', '000831']
#       Image File: ['DICOM', '000832']
#       Image File: ['DICOM', '000833']
#       Image File: ['DICOM', '000834']
#       Image File: ['DICOM', '000835']
#       Image File: ['DICOM', '000836']
#       Image File: ['DICOM', '000837']
#       Image File: ['DICOM', '000838']
#       Image File: ['DICOM', '000839']
#       Image File: ['DICOM', '000840']
#       Image File: ['DICOM', '000841']
#       Image File: ['DICOM', '000842']
#       Image File: ['DICOM', '000843']
#       Image File: ['DICOM', '000844']
#       Image File: ['DICOM', '000845']
#       Image File: ['DICOM', '000846']
#       Image File: ['DICOM', '000847']
#       Image File: ['DICOM', '000848']
#       Image File: ['DICOM', '000849']
#       Image File: ['DICOM', '000850']
#       Image File: ['DICOM', '000851']
#       Image File: ['DICOM', '000852']
#       Image File: ['DICOM', '000853']
#       Image File: ['DICOM', '000854']
#       Image File: ['DICOM', '000855']
#       Image File: ['DICOM', '000856']
#       Image File: ['DICOM', '000857']
#       Image File: ['DICOM', '000858']
#       Image File: ['DICOM', '000859']
#       Image File: ['DICOM', '000860']
#       Image File: ['DICOM', '000861']
#       Image File: ['DICOM', '000862']
#       Image File: ['DICOM', '000863']
#       Image File: ['DICOM', '000864']
#       Image File: ['DICOM', '000865']
#       Image File: ['DICOM', '000866']
#       Image File: ['DICOM', '000867']
#       Image File: ['DICOM', '000868']
#       Image File: ['DICOM', '000869']
#       Image File: ['DICOM', '000870']
#       Image File: ['DICOM', '000871']
#       Image File: ['DICOM', '000872']
#       Image File: ['DICOM', '000873']
#       Image File: ['DICOM', '000874']
#       Image File: ['DICOM', '000875']
#       Image File: ['DICOM', '000876']
#       Image File: ['DICOM', '000877']
#       Image File: ['DICOM', '000878']
#       Image File: ['DICOM', '000879']
#       Image File: ['DICOM', '000880']
#       Image File: ['DICOM', '000881']
#       Image File: ['DICOM', '000882']
#       Image File: ['DICOM', '000883']
#       Image File: ['DICOM', '000884']
#       Image File: ['DICOM', '000885']
#       Image File: ['DICOM', '000886']
#       Image File: ['DICOM', '000887']
#       Image File: ['DICOM', '000888']
#       Image File: ['DICOM', '000889']
#       Image File: ['DICOM', '000890']
#       Image File: ['DICOM', '000891']
#       Image File: ['DICOM', '000892']
#       Image File: ['DICOM', '000893']
#       Image File: ['DICOM', '000894']
#       Image File: ['DICOM', '000895']
#       Image File: ['DICOM', '000896']
#       Image File: ['DICOM', '000897']
#       Image File: ['DICOM', '000898']
#       Image File: ['DICOM', '000899']
#       Image File: ['DICOM', '000900']
#       Image File: ['DICOM', '000901']
#       Image File: ['DICOM', '000902']
#       Image File: ['DICOM', '000903']
#       Image File: ['DICOM', '000904']
#       Image File: ['DICOM', '000905']
#       Image File: ['DICOM', '000906']
#       Image File: ['DICOM', '000907']
#       Image File: ['DICOM', '000908']
#       Image File: ['DICOM', '000909']
#       Image File: ['DICOM', '000910']
#       Image File: ['DICOM', '000911']
#       Image File: ['DICOM', '000912']
#       Image File: ['DICOM', '000913']
#       Image File: ['DICOM', '000914']
#       Image File: ['DICOM', '000915']
#       Image File: ['DICOM', '000916']
#       Image File: ['DICOM', '000917']
#       Image File: ['DICOM', '000918']
#       Image File: ['DICOM', '000919']
#       Image File: ['DICOM', '000920']
#       Image File: ['DICOM', '000921']
#       Image File: ['DICOM', '000922']
#       Image File: ['DICOM', '000923']
#       Image File: ['DICOM', '000924']
#       Image File: ['DICOM', '000925']
#       Image File: ['DICOM', '000926']
#       Image File: ['DICOM', '000927']
#       Image File: ['DICOM', '000928']
#       Image File: ['DICOM', '000929']
#       Image File: ['DICOM', '000930']
#       Image File: ['DICOM', '000931']
#       Image File: ['DICOM', '000932']
#       Image File: ['DICOM', '000933']
#       Image File: ['DICOM', '000934']
#       Image File: ['DICOM', '000935']
#       Image File: ['DICOM', '000936']
#       Image File: ['DICOM', '000937']
#       Image File: ['DICOM', '000938']
#       Image File: ['DICOM', '000939']
#       Image File: ['DICOM', '000940']
#       Image File: ['DICOM', '000941']
#       Image File: ['DICOM', '000942']
#       Image File: ['DICOM', '000943']
#       Image File: ['DICOM', '000944']
#       Image File: ['DICOM', '000945']
#       Image File: ['DICOM', '000946']
#       Image File: ['DICOM', '000947']
#       Image File: ['DICOM', '000948']
#       Image File: ['DICOM', '000949']
#       Image File: ['DICOM', '000950']
#       Image File: ['DICOM', '000951']
#       Image File: ['DICOM', '000952']
#       Image File: ['DICOM', '000953']
#       Image File: ['DICOM', '000954']
#       Image File: ['DICOM', '000955']
#       Image File: ['DICOM', '000956']
#       Image File: ['DICOM', '000957']
#       Image File: ['DICOM', '000958']
#       Image File: ['DICOM', '000959']
#       Image File: ['DICOM', '000960']
#       Image File: ['DICOM', '000961']
#       Image File: ['DICOM', '000962']
#       Image File: ['DICOM', '000963']
#       Image File: ['DICOM', '000964']
#       Image File: ['DICOM', '000965']
#       Image File: ['DICOM', '000966']
#       Image File: ['DICOM', '000967']
#       Image File: ['DICOM', '000968']
#       Image File: ['DICOM', '000969']
#       Image File: ['DICOM', '000970']
#       Image File: ['DICOM', '000971']
#       Image File: ['DICOM', '000972']
#       Image File: ['DICOM', '000973']
#       Image File: ['DICOM', '000974']
#       Image File: ['DICOM', '000975']
#       Image File: ['DICOM', '000976']
#       Image File: ['DICOM', '000977']
#       Image File: ['DICOM', '000978']
#       Image File: ['DICOM', '000979']
#       Image File: ['DICOM', '000980']
#       Image File: ['DICOM', '000981']
#       Image File: ['DICOM', '000982']
#       Image File: ['DICOM', '000983']
#       Image File: ['DICOM', '000984']
#       Image File: ['DICOM', '000985']
#       Image File: ['DICOM', '000986']
#       Image File: ['DICOM', '000987']
#       Image File: ['DICOM', '000988']
#       Image File: ['DICOM', '000989']
#       Image File: ['DICOM', '000990']
#       Image File: ['DICOM', '000991']
#       Image File: ['DICOM', '000992']
#       Image File: ['DICOM', '000993']
#       Image File: ['DICOM', '000994']
#       Image File: ['DICOM', '000995']
#       Image File: ['DICOM', '000996']
#       Image File: ['DICOM', '000997']
#       Image File: ['DICOM', '000998']
#       Image File: ['DICOM', '000999']
#       Image File: ['DICOM', '001000']
#       Image File: ['DICOM', '001001']
#       Image File: ['DICOM', '001002']
#       Image File: ['DICOM', '001003']
#       Image File: ['DICOM', '001004']
#     Series: 1.2.840.113619.2.416.289092425520269769155650107991311775107
#       Image File: ['DICOM', '001005']
#       Image File: ['DICOM', '001006']
#       Image File: ['DICOM', '001007']
#       Image File: ['DICOM', '001008']
#       Image File: ['DICOM', '001009']
#       Image File: ['DICOM', '001010']
#       Image File: ['DICOM', '001011']
#       Image File: ['DICOM', '001012']
#       Image File: ['DICOM', '001013']
#       Image File: ['DICOM', '001014']
#       Image File: ['DICOM', '001015']
#       Image File: ['DICOM', '001016']
#       Image File: ['DICOM', '001017']
#       Image File: ['DICOM', '001018']
#       Image File: ['DICOM', '001019']
#       Image File: ['DICOM', '001020']
#       Image File: ['DICOM', '001021']
#       Image File: ['DICOM', '001022']
#       Image File: ['DICOM', '001023']
#       Image File: ['DICOM', '001024']
#       Image File: ['DICOM', '001025']
#       Image File: ['DICOM', '001026']
#       Image File: ['DICOM', '001027']
#       Image File: ['DICOM', '001028']
#       Image File: ['DICOM', '001029']
#       Image File: ['DICOM', '001030']
#       Image File: ['DICOM', '001031']
#       Image File: ['DICOM', '001032']
#       Image File: ['DICOM', '001033']
#       Image File: ['DICOM', '001034']
#       Image File: ['DICOM', '001035']
#       Image File: ['DICOM', '001036']
#       Image File: ['DICOM', '001037']
#       Image File: ['DICOM', '001038']
#       Image File: ['DICOM', '001039']
#       Image File: ['DICOM', '001040']
#       Image File: ['DICOM', '001041']
#       Image File: ['DICOM', '001042']
#       Image File: ['DICOM', '001043']
#       Image File: ['DICOM', '001044']
#       Image File: ['DICOM', '001045']
#       Image File: ['DICOM', '001046']
#       Image File: ['DICOM', '001047']
#       Image File: ['DICOM', '001048']
#       Image File: ['DICOM', '001049']
#       Image File: ['DICOM', '001050']
#       Image File: ['DICOM', '001051']
#       Image File: ['DICOM', '001052']
#       Image File: ['DICOM', '001053']
#       Image File: ['DICOM', '001054']
#       Image File: ['DICOM', '001055']
#       Image File: ['DICOM', '001056']
#       Image File: ['DICOM', '001057']
#       Image File: ['DICOM', '001058']
#       Image File: ['DICOM', '001059']
#       Image File: ['DICOM', '001060']
#       Image File: ['DICOM', '001061']
#       Image File: ['DICOM', '001062']
#       Image File: ['DICOM', '001063']
#       Image File: ['DICOM', '001064']
#       Image File: ['DICOM', '001065']
#       Image File: ['DICOM', '001066']
#       Image File: ['DICOM', '001067']
#       Image File: ['DICOM', '001068']
#       Image File: ['DICOM', '001069']
#       Image File: ['DICOM', '001070']
#       Image File: ['DICOM', '001071']
#       Image File: ['DICOM', '001072']
#       Image File: ['DICOM', '001073']
#       Image File: ['DICOM', '001074']
#       Image File: ['DICOM', '001075']
#       Image File: ['DICOM', '001076']
#       Image File: ['DICOM', '001077']
#       Image File: ['DICOM', '001078']
#       Image File: ['DICOM', '001079']
#       Image File: ['DICOM', '001080']
#       Image File: ['DICOM', '001081']
#       Image File: ['DICOM', '001082']
#       Image File: ['DICOM', '001083']
#       Image File: ['DICOM', '001084']
#       Image File: ['DICOM', '001085']
#       Image File: ['DICOM', '001086']
#       Image File: ['DICOM', '001087']
#       Image File: ['DICOM', '001088']
#       Image File: ['DICOM', '001089']
#       Image File: ['DICOM', '001090']
#       Image File: ['DICOM', '001091']
#       Image File: ['DICOM', '001092']
#       Image File: ['DICOM', '001093']
#       Image File: ['DICOM', '001094']
#       Image File: ['DICOM', '001095']
#       Image File: ['DICOM', '001096']
#       Image File: ['DICOM', '001097']
#       Image File: ['DICOM', '001098']
#       Image File: ['DICOM', '001099']
#       Image File: ['DICOM', '001100']
#       Image File: ['DICOM', '001101']
#       Image File: ['DICOM', '001102']
#       Image File: ['DICOM', '001103']
#       Image File: ['DICOM', '001104']
#       Image File: ['DICOM', '001105']
#       Image File: ['DICOM', '001106']
#       Image File: ['DICOM', '001107']
#       Image File: ['DICOM', '001108']
#       Image File: ['DICOM', '001109']
#       Image File: ['DICOM', '001110']
#       Image File: ['DICOM', '001111']
#       Image File: ['DICOM', '001112']
#       Image File: ['DICOM', '001113']
#       Image File: ['DICOM', '001114']
#       Image File: ['DICOM', '001115']
#       Image File: ['DICOM', '001116']
#       Image File: ['DICOM', '001117']
#       Image File: ['DICOM', '001118']
#       Image File: ['DICOM', '001119']
#       Image File: ['DICOM', '001120']
#       Image File: ['DICOM', '001121']
#       Image File: ['DICOM', '001122']
#       Image File: ['DICOM', '001123']
#       Image File: ['DICOM', '001124']
#       Image File: ['DICOM', '001125']
#       Image File: ['DICOM', '001126']
#       Image File: ['DICOM', '001127']
#       Image File: ['DICOM', '001128']
#       Image File: ['DICOM', '001129']
#       Image File: ['DICOM', '001130']
#       Image File: ['DICOM', '001131']
#       Image File: ['DICOM', '001132']
#       Image File: ['DICOM', '001133']
#       Image File: ['DICOM', '001134']
#       Image File: ['DICOM', '001135']
#       Image File: ['DICOM', '001136']
#       Image File: ['DICOM', '001137']
#       Image File: ['DICOM', '001138']
#       Image File: ['DICOM', '001139']
#       Image File: ['DICOM', '001140']
#       Image File: ['DICOM', '001141']
#       Image File: ['DICOM', '001142']
#       Image File: ['DICOM', '001143']
#       Image File: ['DICOM', '001144']
#       Image File: ['DICOM', '001145']
#       Image File: ['DICOM', '001146']
#       Image File: ['DICOM', '001147']
#       Image File: ['DICOM', '001148']
#       Image File: ['DICOM', '001149']
#       Image File: ['DICOM', '001150']
#       Image File: ['DICOM', '001151']
#       Image File: ['DICOM', '001152']
#       Image File: ['DICOM', '001153']
#       Image File: ['DICOM', '001154']
#       Image File: ['DICOM', '001155']
#       Image File: ['DICOM', '001156']
#       Image File: ['DICOM', '001157']
#       Image File: ['DICOM', '001158']
#       Image File: ['DICOM', '001159']
#       Image File: ['DICOM', '001160']
#       Image File: ['DICOM', '001161']
#       Image File: ['DICOM', '001162']
#       Image File: ['DICOM', '001163']
#       Image File: ['DICOM', '001164']
#       Image File: ['DICOM', '001165']
#       Image File: ['DICOM', '001166']
#       Image File: ['DICOM', '001167']
#       Image File: ['DICOM', '001168']
#       Image File: ['DICOM', '001169']
#       Image File: ['DICOM', '001170']
#       Image File: ['DICOM', '001171']
#       Image File: ['DICOM', '001172']
#       Image File: ['DICOM', '001173']
#       Image File: ['DICOM', '001174']
#       Image File: ['DICOM', '001175']
#       Image File: ['DICOM', '001176']
#       Image File: ['DICOM', '001177']
#       Image File: ['DICOM', '001178']
#       Image File: ['DICOM', '001179']
#       Image File: ['DICOM', '001180']
#       Image File: ['DICOM', '001181']
#       Image File: ['DICOM', '001182']
#       Image File: ['DICOM', '001183']
#       Image File: ['DICOM', '001184']
#       Image File: ['DICOM', '001185']
#       Image File: ['DICOM', '001186']
#       Image File: ['DICOM', '001187']
#       Image File: ['DICOM', '001188']
#       Image File: ['DICOM', '001189']
#       Image File: ['DICOM', '001190']
#       Image File: ['DICOM', '001191']
#       Image File: ['DICOM', '001192']
#       Image File: ['DICOM', '001193']
#       Image File: ['DICOM', '001194']
#       Image File: ['DICOM', '001195']
#       Image File: ['DICOM', '001196']
#       Image File: ['DICOM', '001197']
#       Image File: ['DICOM', '001198']
#       Image File: ['DICOM', '001199']
#       Image File: ['DICOM', '001200']
#       Image File: ['DICOM', '001201']
#       Image File: ['DICOM', '001202']
#       Image File: ['DICOM', '001203']
#       Image File: ['DICOM', '001204']
#       Image File: ['DICOM', '001205']
#       Image File: ['DICOM', '001206']
#       Image File: ['DICOM', '001207']
#       Image File: ['DICOM', '001208']
#       Image File: ['DICOM', '001209']
#       Image File: ['DICOM', '001210']
#       Image File: ['DICOM', '001211']
#       Image File: ['DICOM', '001212']
#       Image File: ['DICOM', '001213']
#       Image File: ['DICOM', '001214']
#       Image File: ['DICOM', '001215']
#       Image File: ['DICOM', '001216']
#       Image File: ['DICOM', '001217']
#       Image File: ['DICOM', '001218']
#       Image File: ['DICOM', '001219']
#       Image File: ['DICOM', '001220']
#       Image File: ['DICOM', '001221']
#       Image File: ['DICOM', '001222']
#       Image File: ['DICOM', '001223']
#       Image File: ['DICOM', '001224']
#       Image File: ['DICOM', '001225']
#       Image File: ['DICOM', '001226']
#       Image File: ['DICOM', '001227']
#       Image File: ['DICOM', '001228']
#       Image File: ['DICOM', '001229']
#       Image File: ['DICOM', '001230']
#       Image File: ['DICOM', '001231']
#       Image File: ['DICOM', '001232']
#       Image File: ['DICOM', '001233']
#       Image File: ['DICOM', '001234']
#       Image File: ['DICOM', '001235']
#       Image File: ['DICOM', '001236']
#       Image File: ['DICOM', '001237']
#       Image File: ['DICOM', '001238']
#       Image File: ['DICOM', '001239']
#       Image File: ['DICOM', '001240']
#       Image File: ['DICOM', '001241']
#       Image File: ['DICOM', '001242']
#       Image File: ['DICOM', '001243']
#       Image File: ['DICOM', '001244']
#       Image File: ['DICOM', '001245']
#       Image File: ['DICOM', '001246']
#       Image File: ['DICOM', '001247']
#       Image File: ['DICOM', '001248']
#       Image File: ['DICOM', '001249']
#       Image File: ['DICOM', '001250']
#       Image File: ['DICOM', '001251']
#       Image File: ['DICOM', '001252']
#       Image File: ['DICOM', '001253']
#       Image File: ['DICOM', '001254']
# ...
#       Image File: ['DICOM', '002107']
#       Image File: ['DICOM', '002108']
#       Image File: ['DICOM', '002109']
#       Image File: ['DICOM', '002110']
#       Image File: ['DICOM', '002111']
#       Image File: ['DICOM', '002112']
#       Image File: ['DICOM', '002113']
#       Image File: ['DICOM', '002114']
#       Image File: ['DICOM', '002115']
#       Image File: ['DICOM', '002116']
#       Image File: ['DICOM', '002117']
#       Image File: ['DICOM', '002118']
#       Image File: ['DICOM', '002119']
#       Image File: ['DICOM', '002120']
#       Image File: ['DICOM', '002121']
#       Image File: ['DICOM', '002122']
#       Image File: ['DICOM', '002123']
#       Image File: ['DICOM', '002124']
#       Image File: ['DICOM', '002125']
#       Image File: ['DICOM', '002126']
#       Image File: ['DICOM', '002127']
#       Image File: ['DICOM', '002128']
#       Image File: ['DICOM', '002129']
#       Image File: ['DICOM', '002130']
#       Image File: ['DICOM', '002131']
#       Image File: ['DICOM', '002132']
#       Image File: ['DICOM', '002133']
#       Image File: ['DICOM', '002134']
#       Image File: ['DICOM', '002135']
#       Image File: ['DICOM', '002136']
#       Image File: ['DICOM', '002137']
#       Image File: ['DICOM', '002138']
#       Image File: ['DICOM', '002139']
#       Image File: ['DICOM', '002140']
#       Image File: ['DICOM', '002141']
#       Image File: ['DICOM', '002142']
#       Image File: ['DICOM', '002143']
#       Image File: ['DICOM', '002144']
#       Image File: ['DICOM', '002145']
#       Image File: ['DICOM', '002146']
#       Image File: ['DICOM', '002147']
#       Image File: ['DICOM', '002148']
#       Image File: ['DICOM', '002149']
#       Image File: ['DICOM', '002150']
#       Image File: ['DICOM', '002151']
#       Image File: ['DICOM', '002152']
#       Image File: ['DICOM', '002153']
#       Image File: ['DICOM', '002154']
#       Image File: ['DICOM', '002155']
#       Image File: ['DICOM', '002156']
#       Image File: ['DICOM', '002157']
#       Image File: ['DICOM', '002158']
#       Image File: ['DICOM', '002159']
#       Image File: ['DICOM', '002160']
#       Image File: ['DICOM', '002161']
#       Image File: ['DICOM', '002162']
#       Image File: ['DICOM', '002163']
#       Image File: ['DICOM', '002164']
#       Image File: ['DICOM', '002165']
#       Image File: ['DICOM', '002166']
#       Image File: ['DICOM', '002167']
#       Image File: ['DICOM', '002168']
#       Image File: ['DICOM', '002169']
#       Image File: ['DICOM', '002170']
#       Image File: ['DICOM', '002171']
#       Image File: ['DICOM', '002172']
#       Image File: ['DICOM', '002173']
#       Image File: ['DICOM', '002174']
#       Image File: ['DICOM', '002175']
#       Image File: ['DICOM', '002176']
#       Image File: ['DICOM', '002177']
#       Image File: ['DICOM', '002178']
#       Image File: ['DICOM', '002179']
#       Image File: ['DICOM', '002180']
#       Image File: ['DICOM', '002181']
#       Image File: ['DICOM', '002182']
#       Image File: ['DICOM', '002183']
#       Image File: ['DICOM', '002184']
#       Image File: ['DICOM', '002185']
#       Image File: ['DICOM', '002186']
#       Image File: ['DICOM', '002187']
#       Image File: ['DICOM', '002188']
#       Image File: ['DICOM', '002189']
#     Series: 1.2.840.113619.2.416.235420744137834152204035779555244077890
#       Image File: ['DICOM', '002190']
#       Image File: ['DICOM', '002191']
#       Image File: ['DICOM', '002192']
#       Image File: ['DICOM', '002193']
#       Image File: ['DICOM', '002194']
#       Image File: ['DICOM', '002195']
#       Image File: ['DICOM', '002196']
#       Image File: ['DICOM', '002197']
#       Image File: ['DICOM', '002198']
#       Image File: ['DICOM', '002199']
#       Image File: ['DICOM', '002200']
#       Image File: ['DICOM', '002201']
#       Image File: ['DICOM', '002202']
#       Image File: ['DICOM', '002203']
#       Image File: ['DICOM', '002204']
#       Image File: ['DICOM', '002205']
#       Image File: ['DICOM', '002206']
#       Image File: ['DICOM', '002207']
#       Image File: ['DICOM', '002208']
#       Image File: ['DICOM', '002209']
#       Image File: ['DICOM', '002210']
#       Image File: ['DICOM', '002211']
#       Image File: ['DICOM', '002212']
#       Image File: ['DICOM', '002213']
#       Image File: ['DICOM', '002214']
#       Image File: ['DICOM', '002215']
#       Image File: ['DICOM', '002216']
#       Image File: ['DICOM', '002217']
#       Image File: ['DICOM', '002218']
#       Image File: ['DICOM', '002219']
#       Image File: ['DICOM', '002220']
#       Image File: ['DICOM', '002221']
#       Image File: ['DICOM', '002222']
#       Image File: ['DICOM', '002223']
#       Image File: ['DICOM', '002224']
#       Image File: ['DICOM', '002225']
#       Image File: ['DICOM', '002226']
#       Image File: ['DICOM', '002227']
#       Image File: ['DICOM', '002228']
#       Image File: ['DICOM', '002229']
#       Image File: ['DICOM', '002230']
#       Image File: ['DICOM', '002231']
#       Image File: ['DICOM', '002232']
#       Image File: ['DICOM', '002233']
#       Image File: ['DICOM', '002234']
#       Image File: ['DICOM', '002235']
#       Image File: ['DICOM', '002236']
#       Image File: ['DICOM', '002237']
#       Image File: ['DICOM', '002238']
#       Image File: ['DICOM', '002239']
#       Image File: ['DICOM', '002240']
#       Image File: ['DICOM', '002241']
#       Image File: ['DICOM', '002242']
#       Image File: ['DICOM', '002243']
#       Image File: ['DICOM', '002244']
#       Image File: ['DICOM', '002245']
#       Image File: ['DICOM', '002246']
#       Image File: ['DICOM', '002247']
#       Image File: ['DICOM', '002248']
#       Image File: ['DICOM', '002249']
#       Image File: ['DICOM', '002250']
#       Image File: ['DICOM', '002251']
#       Image File: ['DICOM', '002252']
#       Image File: ['DICOM', '002253']
#       Image File: ['DICOM', '002254']
#       Image File: ['DICOM', '002255']
#       Image File: ['DICOM', '002256']
#       Image File: ['DICOM', '002257']
#       Image File: ['DICOM', '002258']
#       Image File: ['DICOM', '002259']
#       Image File: ['DICOM', '002260']
#       Image File: ['DICOM', '002261']
#       Image File: ['DICOM', '002262']
#       Image File: ['DICOM', '002263']
#       Image File: ['DICOM', '002264']
#       Image File: ['DICOM', '002265']
#       Image File: ['DICOM', '002266']
#       Image File: ['DICOM', '002267']
#       Image File: ['DICOM', '002268']
#       Image File: ['DICOM', '002269']
#       Image File: ['DICOM', '002270']
#       Image File: ['DICOM', '002271']
#     Series: 1.2.840.113619.2.416.199294614901944573766568525174161625146
#       Image File: ['DICOM', '002272']
#       Image File: ['DICOM', '002273']
#       Image File: ['DICOM', '002274']
#       Image File: ['DICOM', '002275']
#       Image File: ['DICOM', '002276']
#       Image File: ['DICOM', '002277']
#       Image File: ['DICOM', '002278']
#       Image File: ['DICOM', '002279']
#       Image File: ['DICOM', '002280']
#       Image File: ['DICOM', '002281']
#       Image File: ['DICOM', '002282']
#       Image File: ['DICOM', '002283']
#       Image File: ['DICOM', '002284']
#       Image File: ['DICOM', '002285']
#       Image File: ['DICOM', '002286']
#       Image File: ['DICOM', '002287']
#       Image File: ['DICOM', '002288']
#       Image File: ['DICOM', '002289']
#       Image File: ['DICOM', '002290']
#       Image File: ['DICOM', '002291']
#       Image File: ['DICOM', '002292']
#       Image File: ['DICOM', '002293']
#       Image File: ['DICOM', '002294']
#       Image File: ['DICOM', '002295']
#       Image File: ['DICOM', '002296']
#       Image File: ['DICOM', '002297']
#       Image File: ['DICOM', '002298']
#       Image File: ['DICOM', '002299']
#       Image File: ['DICOM', '002300']
#       Image File: ['DICOM', '002301']
#       Image File: ['DICOM', '002302']
#       Image File: ['DICOM', '002303']
#       Image File: ['DICOM', '002304']
#       Image File: ['DICOM', '002305']
#       Image File: ['DICOM', '002306']
#       Image File: ['DICOM', '002307']
#       Image File: ['DICOM', '002308']
#       Image File: ['DICOM', '002309']
#       Image File: ['DICOM', '002310']
#       Image File: ['DICOM', '002311']
#       Image File: ['DICOM', '002312']
#       Image File: ['DICOM', '002313']
#       Image File: ['DICOM', '002314']
#       Image File: ['DICOM', '002315']
#       Image File: ['DICOM', '002316']
#       Image File: ['DICOM', '002317']
#       Image File: ['DICOM', '002318']
#       Image File: ['DICOM', '002319']
#       Image File: ['DICOM', '002320']
#       Image File: ['DICOM', '002321']
#       Image File: ['DICOM', '002322']
#       Image File: ['DICOM', '002323']
#       Image File: ['DICOM', '002324']
#       Image File: ['DICOM', '002325']
#       Image File: ['DICOM', '002326']
#       Image File: ['DICOM', '002327']
#       Image File: ['DICOM', '002328']
#       Image File: ['DICOM', '002329']
#       Image File: ['DICOM', '002330']
#       Image File: ['DICOM', '002331']
#       Image File: ['DICOM', '002332']
#       Image File: ['DICOM', '002333']
#       Image File: ['DICOM', '002334']
#       Image File: ['DICOM', '002335']
#       Image File: ['DICOM', '002336']
#       Image File: ['DICOM', '002337']
#       Image File: ['DICOM', '002338']
#       Image File: ['DICOM', '002339']
#       Image File: ['DICOM', '002340']
#       Image File: ['DICOM', '002341']
#       Image File: ['DICOM', '002342']
#       Image File: ['DICOM', '002343']
#       Image File: ['DICOM', '002344']
#       Image File: ['DICOM', '002345']
#       Image File: ['DICOM', '002346']
#       Image File: ['DICOM', '002347']
#       Image File: ['DICOM', '002348']
#       Image File: ['DICOM', '002349']
#       Image File: ['DICOM', '002350']
#       Image File: ['DICOM', '002351']
#       Image File: ['DICOM', '002352']
#       Image File: ['DICOM', '002353']
#       Image File: ['DICOM', '002354']
#       Image File: ['DICOM', '002355']
#       Image File: ['DICOM', '002356']
#       Image File: ['DICOM', '002357']
#       Image File: ['DICOM', '002358']
#       Image File: ['DICOM', '002359']
#       Image File: ['DICOM', '002360']
#       Image File: ['DICOM', '002361']
#       Image File: ['DICOM', '002362']
#       Image File: ['DICOM', '002363']
#       Image File: ['DICOM', '002364']
#       Image File: ['DICOM', '002365']
#       Image File: ['DICOM', '002366']
#       Image File: ['DICOM', '002367']
#       Image File: ['DICOM', '002368']
#       Image File: ['DICOM', '002369']
#       Image File: ['DICOM', '002370']
#       Image File: ['DICOM', '002371']
#     Series: 1.2.840.113619.2.416.178103812539468622858374801196637347559
#       Image File: ['DICOM', '002372']
#       Image File: ['DICOM', '002373']
#       Image File: ['DICOM', '002374']
#       Image File: ['DICOM', '002375']
#       Image File: ['DICOM', '002376']
#       Image File: ['DICOM', '002377']
#       Image File: ['DICOM', '002378']
#       Image File: ['DICOM', '002379']
#       Image File: ['DICOM', '002380']
#       Image File: ['DICOM', '002381']
#       Image File: ['DICOM', '002382']
#       Image File: ['DICOM', '002383']
#       Image File: ['DICOM', '002384']
#       Image File: ['DICOM', '002385']
#       Image File: ['DICOM', '002386']
#       Image File: ['DICOM', '002387']
#       Image File: ['DICOM', '002388']
#       Image File: ['DICOM', '002389']
#       Image File: ['DICOM', '002390']
#       Image File: ['DICOM', '002391']
#       Image File: ['DICOM', '002392']
#       Image File: ['DICOM', '002393']
#       Image File: ['DICOM', '002394']
#       Image File: ['DICOM', '002395']
#       Image File: ['DICOM', '002396']
#       Image File: ['DICOM', '002397']
#       Image File: ['DICOM', '002398']
#       Image File: ['DICOM', '002399']
#       Image File: ['DICOM', '002400']
#       Image File: ['DICOM', '002401']
#       Image File: ['DICOM', '002402']
#       Image File: ['DICOM', '002403']
#       Image File: ['DICOM', '002404']
#       Image File: ['DICOM', '002405']
#       Image File: ['DICOM', '002406']
#       Image File: ['DICOM', '002407']
#       Image File: ['DICOM', '002408']
#       Image File: ['DICOM', '002409']
#       Image File: ['DICOM', '002410']
#       Image File: ['DICOM', '002411']
#       Image File: ['DICOM', '002412']
#       Image File: ['DICOM', '002413']
#       Image File: ['DICOM', '002414']
#       Image File: ['DICOM', '002415']
#       Image File: ['DICOM', '002416']
#       Image File: ['DICOM', '002417']
#       Image File: ['DICOM', '002418']
#       Image File: ['DICOM', '002419']
#       Image File: ['DICOM', '002420']
#       Image File: ['DICOM', '002421']
#       Image File: ['DICOM', '002422']
#       Image File: ['DICOM', '002423']
#       Image File: ['DICOM', '002424']
#       Image File: ['DICOM', '002425']
#       Image File: ['DICOM', '002426']
#       Image File: ['DICOM', '002427']
#       Image File: ['DICOM', '002428']
#       Image File: ['DICOM', '002429']
#       Image File: ['DICOM', '002430']
#       Image File: ['DICOM', '002431']
#       Image File: ['DICOM', '002432']
#       Image File: ['DICOM', '002433']
#       Image File: ['DICOM', '002434']
#     Series: 1.2.840.113619.2.416.200764377738852322028542708289030247687
#       Image File: ['DICOM', '002435']
#       Image File: ['DICOM', '002436']
#       Image File: ['DICOM', '002437']
#       Image File: ['DICOM', '002438']
#       Image File: ['DICOM', '002439']
#       Image File: ['DICOM', '002440']
#       Image File: ['DICOM', '002441']
#       Image File: ['DICOM', '002442']
#       Image File: ['DICOM', '002443']
#       Image File: ['DICOM', '002444']
#       Image File: ['DICOM', '002445']
#       Image File: ['DICOM', '002446']
#       Image File: ['DICOM', '002447']
#       Image File: ['DICOM', '002448']
#       Image File: ['DICOM', '002449']
#       Image File: ['DICOM', '002450']
#       Image File: ['DICOM', '002451']
#       Image File: ['DICOM', '002452']
#       Image File: ['DICOM', '002453']
#       Image File: ['DICOM', '002454']
#       Image File: ['DICOM', '002455']
#       Image File: ['DICOM', '002456']
#       Image File: ['DICOM', '002457']
#       Image File: ['DICOM', '002458']
#       Image File: ['DICOM', '002459']
#       Image File: ['DICOM', '002460']
#       Image File: ['DICOM', '002461']
#       Image File: ['DICOM', '002462']
#       Image File: ['DICOM', '002463']
#       Image File: ['DICOM', '002464']
#       Image File: ['DICOM', '002465']
#       Image File: ['DICOM', '002466']
#       Image File: ['DICOM', '002467']
#       Image File: ['DICOM', '002468']
#       Image File: ['DICOM', '002469']
#       Image File: ['DICOM', '002470']
#       Image File: ['DICOM', '002471']
#       Image File: ['DICOM', '002472']
#       Image File: ['DICOM', '002473']
#       Image File: ['DICOM', '002474']
#       Image File: ['DICOM', '002475']
#       Image File: ['DICOM', '002476']
#       Image File: ['DICOM', '002477']
#       Image File: ['DICOM', '002478']
#       Image File: ['DICOM', '002479']
#       Image File: ['DICOM', '002480']
#       Image File: ['DICOM', '002481']
#       Image File: ['DICOM', '002482']
#       Image File: ['DICOM', '002483']
#       Image File: ['DICOM', '002484']
#       Image File: ['DICOM', '002485']
#       Image File: ['DICOM', '002486']
#       Image File: ['DICOM', '002487']
#       Image File: ['DICOM', '002488']
#       Image File: ['DICOM', '002489']
#       Image File: ['DICOM', '002490']
#       Image File: ['DICOM', '002491']
#       Image File: ['DICOM', '002492']
#       Image File: ['DICOM', '002493']
#       Image File: ['DICOM', '002494']
#       Image File: ['DICOM', '002495']
#       Image File: ['DICOM', '002496']
#       Image File: ['DICOM', '002497']
#       Image File: ['DICOM', '002498']
#       Image File: ['DICOM', '002499']
#       Image File: ['DICOM', '002500']
#       Image File: ['DICOM', '002501']
#       Image File: ['DICOM', '002502']
#       Image File: ['DICOM', '002503']
#       Image File: ['DICOM', '002504']
#       Image File: ['DICOM', '002505']
#       Image File: ['DICOM', '002506']
#       Image File: ['DICOM', '002507']
#       Image File: ['DICOM', '002508']
#       Image File: ['DICOM', '002509']
#       Image File: ['DICOM', '002510']
#       Image File: ['DICOM', '002511']
#       Image File: ['DICOM', '002512']
#       Image File: ['DICOM', '002513']
#       Image File: ['DICOM', '002514']
#       Image File: ['DICOM', '002515']
#       Image File: ['DICOM', '002516']
#     Series: 1.2.840.113619.2.416.107286101862165151620817523026312476513
#       Image File: ['DICOM', '002517']

# %% [markdown]
# # Investigating attributes
#
# Investigating attributes of one dicom image

# %%
import pydicom
import os
import numpy as np

# Get the first file in the directory
first_file = sorted(os.listdir(dicom_folder))[0]
dicom_path = os.path.join(dicom_folder, first_file)

# Read the DICOM file
dicomfile = pydicom.dcmread(dicom_path)

# Print all available keys (DICOM tags)
print("Available DICOM attributes:\n")
for elem in dicomfile.dir():
    print(elem)
# Out:
# Available DICOM attributes:
#
# AccessionNumber
# AcquisitionDate
# AcquisitionNumber
# AcquisitionTime
# AdditionalPatientHistory
# BitsAllocated
# BitsStored
# BodyPartExamined
# Columns
# ContentDate
# ContentTime
# ConvolutionKernel
# DataCollectionDiameter
# DeviceSerialNumber
# DistanceSourceToDetector
# DistanceSourceToPatient
# Exposure
# ExposureInuAs
# ExposureTime
# FilterType
# FocalSpots
# FrameOfReferenceUID
# GantryDetectorTilt
# GeneratorPower
# HighBit
# ImageOrientationPatient
# ImagePositionPatient
# ImageType
# InstanceCreationDate
# InstanceCreationTime
# InstanceNumber
# InstitutionName
# IrradiationEventUID
# KVP
# Manufacturer
# ManufacturerModelName
# Modality
# NameOfPhysiciansReadingStudy
# NumberOfFrames
# OperatorsName
# OtherPatientIDs
# OtherPatientIDsSequence
# PatientAge
# PatientBirthDate
# PatientID
# PatientName
# PatientPosition
# PatientSex
# PerformedProcedureStepDescription
# PerformedProcedureStepID
# PerformedProcedureStepStartDate
# PerformedProcedureStepStartTime
# PerformingPhysicianName
# PhotometricInterpretation
# PixelData
# PixelRepresentation
# PixelSpacing
# PlacerOrderNumberImagingServiceRequest
# PositionReferenceIndicator
# ProtocolName
# ReconstructionDiameter
# ReferencedStudySequence
# ReferringPhysicianName
# RequestAttributesSequence
# RequestingPhysician
# RescaleIntercept
# RescaleSlope
# RescaleType
# RotationDirection
# Rows
# SOPClassUID
# SOPInstanceUID
# SamplesPerPixel
# ScanOptions
# SeriesDate
# SeriesDescription
# SeriesInstanceUID
# SeriesNumber
# SeriesTime
# SingleCollimationWidth
# SliceLocation
# SliceThickness
# SoftwareVersions
# SpacingBetweenSlices
# SpecificCharacterSet
# StationName
# StudyDate
# StudyDescription
# StudyID
# StudyInstanceUID
# StudyTime
# TableHeight
# TableSpeed
# TotalCollimationWidth
# WindowCenter
# WindowWidth
# XRayTubeCurrent

# %% [markdown]
# # Load all DICOM images

# %%
def load_dicom_series(folder):
    slices = []
    for filename in sorted(os.listdir(folder)):  
        filepath = os.path.join(folder, filename)
        dicom_slice = pydicom.dcmread(filepath)

        # Skip non-image files
        if dicom_slice.Modality != "CT" or "PixelData" not in dicom_slice:
            continue
        if hasattr(dicom_slice, "ImagePositionPatient"):
            image_type = dicom_slice.get('ImageType')
            if image_type[0] == "ORIGINAL":
                print(f"{filename}: Modality = {dicom_slice.Modality}, ImageType = {dicom_slice.get('ImageType')}")
            else:
                continue
        
        slices.append(dicom_slice)
    
    return slices

dicom_slices = load_dicom_series(dicom_folder)
print(f"Loaded {len(dicom_slices)} valid CT slices.")
# Out:
# 000000: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'LOCALIZER']
# 000001: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'LOCALIZER']
# 000002: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000003: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000004: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000005: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000006: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000007: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000008: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000009: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000010: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000011: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000012: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000013: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000014: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000015: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000016: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000017: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000018: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000019: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000020: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000021: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000022: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000023: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000024: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000025: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000026: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000027: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000028: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000029: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000030: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000031: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000032: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000033: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000034: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000035: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000036: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000037: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000038: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000039: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000040: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000041: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000042: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000043: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000044: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000045: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000046: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000047: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000048: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000049: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000050: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000051: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000052: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000053: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000054: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000055: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000056: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000057: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000058: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000059: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000060: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000061: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000062: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000063: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000064: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000065: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000066: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000067: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000068: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000069: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000070: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000071: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000072: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000073: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000074: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000075: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000076: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000077: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000078: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000079: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000080: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000081: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000082: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000083: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000084: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000085: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000086: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000087: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000088: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000089: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000090: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000091: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000092: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000093: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000094: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000095: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000096: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000097: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000098: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000099: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000100: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000101: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000102: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000103: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000104: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000105: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000106: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000107: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000108: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000109: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000110: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000111: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000112: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000113: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000114: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000115: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000116: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000117: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000118: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000119: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000120: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000121: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000122: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000123: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000124: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000125: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000126: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000127: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000128: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000129: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000130: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000131: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000132: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000133: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000134: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000135: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000136: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000137: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000138: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000139: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000140: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000141: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000142: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000143: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000144: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000145: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000146: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000147: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000148: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000149: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000150: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000151: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000152: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000153: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000154: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000155: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000156: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000157: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000158: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000159: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000160: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000161: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000162: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000163: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000164: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000165: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000166: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000167: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000168: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000169: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000170: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000171: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000172: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000173: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000174: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000175: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000176: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000177: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000178: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000179: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000180: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000181: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000182: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000183: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000184: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000185: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000186: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000187: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000188: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000189: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000190: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000191: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000192: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000193: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000194: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000195: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000196: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000197: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000198: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000199: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000200: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000201: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000202: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000203: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000204: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000205: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000206: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000207: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000208: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000209: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000210: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000211: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000212: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000213: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000214: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000215: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000216: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000217: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000218: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000219: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000220: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000221: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000222: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000223: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000224: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000225: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000226: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000227: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000228: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000229: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000230: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000231: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000232: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000233: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000234: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000235: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000236: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000237: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000238: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000239: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000240: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000241: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000242: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000243: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000244: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000245: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000246: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000247: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000248: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000249: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000250: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000251: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000252: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000253: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000254: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000255: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000256: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000257: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000258: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000259: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000260: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000261: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000262: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000263: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000264: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000265: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000266: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000267: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000268: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000269: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000270: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000271: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000272: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000273: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000274: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000275: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000276: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000277: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000278: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000279: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000280: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000281: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000282: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000283: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000284: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000285: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000286: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000287: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000288: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000289: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000290: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000291: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000292: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000293: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000294: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000295: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000296: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000297: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000298: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000299: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000300: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000301: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000302: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000303: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000304: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000305: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000306: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000307: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000308: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000309: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000310: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000311: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000312: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000313: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000314: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000315: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000316: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000317: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000318: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000319: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000320: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000321: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000322: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000323: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000324: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000325: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000326: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000327: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000328: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000329: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000330: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000331: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000332: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000333: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000334: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000335: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000336: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000337: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000338: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000339: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000340: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000341: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000342: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000343: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000344: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000345: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000346: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000347: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000348: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000349: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000350: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000351: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000352: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000353: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000354: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000355: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000356: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000357: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000358: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000359: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000360: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000361: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000362: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000363: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000364: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000365: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000366: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000367: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000368: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000369: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000370: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000371: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000372: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000373: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000374: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000375: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000376: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000377: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000378: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000379: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000380: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000381: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000382: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000383: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000384: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000385: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000386: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000387: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000388: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000389: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000390: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000391: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000392: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000393: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000394: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000395: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000396: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000397: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000398: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000399: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000400: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000401: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000402: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000403: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000404: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000405: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000406: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000407: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000408: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000409: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000410: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000411: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000412: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000413: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000414: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000415: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000416: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000417: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000418: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000419: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000420: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000421: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000422: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000423: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000424: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000425: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000426: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000427: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000428: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000429: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000430: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000431: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000432: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000433: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000434: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000435: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000436: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000437: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000438: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000439: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000440: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000441: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000442: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000443: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000444: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000445: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000446: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000447: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000448: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000449: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000450: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000451: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000452: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000453: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000454: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000455: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000456: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000457: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000458: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000459: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000460: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000461: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000462: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000463: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000464: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000465: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000466: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000467: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000468: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000469: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000470: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000471: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000472: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000473: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000474: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000475: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000476: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000477: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000478: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000479: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000480: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000481: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000482: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000483: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000484: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000485: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000486: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000487: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000488: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000489: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000490: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000491: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000492: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000493: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000494: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000495: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000496: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000497: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000498: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000499: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000500: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000501: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000502: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000503: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000504: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000505: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000506: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000507: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000508: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000509: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000510: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000511: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000512: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000513: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000514: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000515: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000516: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000517: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000518: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000519: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000520: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000521: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000522: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000523: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000524: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000525: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000526: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000527: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000528: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000529: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000530: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000531: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000532: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000533: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000534: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000535: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000536: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000537: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000538: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000539: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000540: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000541: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000542: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000543: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000544: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000545: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000546: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000547: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000548: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000549: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000550: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000551: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000552: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000553: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000554: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000555: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000556: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000557: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000558: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000559: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000560: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000561: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000562: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000563: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000564: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000565: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000566: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000567: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000568: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000569: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000570: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000571: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000572: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000573: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000574: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000575: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000576: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000577: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000578: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000579: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000580: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000581: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000582: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000583: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000584: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000585: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000586: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000587: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000588: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000589: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000590: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000591: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000592: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000593: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000594: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000595: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000596: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000597: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000598: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000599: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000600: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000601: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000602: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000603: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000604: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000605: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000606: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000607: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000608: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000609: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000610: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000611: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000612: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000613: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000614: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000615: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000616: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000617: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000618: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000619: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000620: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000621: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000622: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000623: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000624: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000625: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000626: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000627: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000628: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000629: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000630: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000631: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000632: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000633: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000634: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000635: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000636: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000637: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000638: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000639: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000640: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000641: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000642: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000643: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000644: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000645: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000646: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000647: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000648: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000649: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000650: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000651: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000652: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000653: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000654: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000655: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000656: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000657: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000658: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000659: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000660: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000661: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000662: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000663: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000664: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000665: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000666: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000667: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000668: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000669: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000670: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000671: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000672: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000673: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000674: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000675: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000676: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000677: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000678: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000679: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000680: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000681: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000682: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000683: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000684: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000685: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000686: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000687: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000688: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000689: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000690: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000691: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000692: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000693: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000694: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000695: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000696: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000697: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000698: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000699: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000700: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000701: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000702: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000703: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 000704: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# ...
# 001774: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001775: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001776: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001777: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001778: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001779: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001780: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001781: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001782: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001783: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001784: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001785: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001786: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001787: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001788: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001789: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001790: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001791: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001792: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001793: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001794: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001795: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001796: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001797: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001798: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001799: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001800: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001801: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001802: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001803: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001804: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001805: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001806: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001807: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001808: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001809: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001810: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001811: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001812: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001813: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001814: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001815: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001816: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001817: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001818: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001819: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001820: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001821: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001822: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001823: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001824: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001825: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001826: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001827: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001828: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001829: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001830: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001831: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001832: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001833: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001834: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001835: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001836: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001837: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001838: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001839: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001840: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001841: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001842: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001843: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001844: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001845: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001846: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001847: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001848: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001849: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001850: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001851: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001852: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001853: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001854: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001855: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001856: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001857: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001858: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001859: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001860: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001861: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001862: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001863: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001864: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001865: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001866: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001867: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001868: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001869: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001870: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001871: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001872: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001873: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001874: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001875: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001876: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001877: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001878: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001879: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001880: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001881: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001882: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001883: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001884: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001885: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001886: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001887: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001888: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001889: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001890: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001891: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001892: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001893: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001894: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001895: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001896: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001897: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001898: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001899: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001900: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001901: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001902: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001903: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001904: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001905: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001906: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001907: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001908: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001909: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001910: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001911: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001912: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001913: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001914: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001915: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001916: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001917: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001918: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001919: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001920: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001921: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001922: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001923: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001924: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001925: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001926: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001927: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001928: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001929: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001930: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001931: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001932: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001933: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001934: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001935: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001936: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001937: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001938: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001939: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001940: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001941: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001942: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001943: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001944: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001945: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001946: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001947: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001948: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001949: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001950: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001951: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001952: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001953: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001954: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001955: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001956: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001957: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001958: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001959: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001960: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001961: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001962: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001963: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001964: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001965: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001966: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001967: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001968: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001969: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001970: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001971: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001972: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001973: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001974: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001975: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001976: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001977: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001978: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001979: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001980: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001981: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001982: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001983: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001984: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001985: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001986: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001987: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001988: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001989: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001990: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001991: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001992: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001993: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001994: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001995: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001996: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001997: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001998: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 001999: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 002000: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 002001: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 002002: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 002003: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 002004: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 002005: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 002006: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# 002007: Modality = CT, ImageType = ['ORIGINAL', 'PRIMARY', 'AXIAL']
# Loaded 2009 valid CT slices.

# %% [markdown]
# # Find good slices
#
# Manually inspecting the data confirmes which slices we need to keep.
#
# Depending on the format you might need to do ``pip install pylibjpeg pylibjpeg-libjpeg pylibjpeg-openjpeg`` first.

# %%
import matplotlib.pyplot as plt

img = dicom_slices[200]
plt.imshow(img.pixel_array, cmap="gray")
plt.show()

# %%
# Select the relevant slice range
start, end = good_slice_indices
right_slices = dicom_slices[start:end+1]
len(right_slices)
# Out:
# 1003

# %% [markdown]
# # Get Hounsfields units
# Turns slices into one three dimensional grid of HU values

# %%
def get_hu_values(dicom_slices):
    # Sort slices by ImagePositionPatient (important for correct stacking)
    dicom_slices.sort(key=lambda x: float(x.ImagePositionPatient[2]))
    image_stack = np.stack([s.pixel_array for s in dicom_slices]).astype(np.int16)
    
    # Convert pixel values to HU
    for i, s in enumerate(dicom_slices):
        intercept = s.RescaleIntercept
        slope = s.RescaleSlope
        image_stack[i] = slope * image_stack[i] + intercept

    return image_stack

hu_volume = get_hu_values(right_slices)

# %%
def get_spacing(dicom_slices):
    pixel_spacing = dicom_slices[0].PixelSpacing  # [row_spacing, col_spacing]
    slice_thickness = getattr(dicom_slices[0], "SliceThickness", None)
    spacing_between_slices = getattr(dicom_slices[0], "SpacingBetweenSlices", None)
    # Use SpacingBetweenSlices if it makes more sense
    slice_thickness = spacing_between_slices

    return np.array([slice_thickness, pixel_spacing[0], pixel_spacing[1]])

voxel_size = get_spacing(dicom_slices)

print(f"\nVoxel Size (mm):\n"
      f"  Slice Thickness: {voxel_size[0]:.2f} mm\n"
      f"  Pixel Spacing (Row): {voxel_size[1]:.2f} mm\n"
      f"  Pixel Spacing (Column): {voxel_size[2]:.2f} mm")
# Out:
# Voxel Size (mm):
#   Slice Thickness: 10.00 mm
#   Pixel Spacing (Row): 0.64 mm
#   Pixel Spacing (Column): 0.65 mm

# %% [markdown]
# **Note:** The slice thickness is probably wrong, it is more likely that the resolution is 0.64mm in all dimensions

# %%
np.save(output_folder, hu_volume)
